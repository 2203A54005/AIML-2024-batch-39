# %% [markdown]
# 1. Lists

# %%
import numpy as np
list1=[1,2,3]
array1=np.array(list1)
print("list is ",list1)
print("here is the array",array1)
# Out:
# list is  [1, 2, 3]
# here is the array [1 2 3]

# %% [markdown]
# Arrays

# %%
import numpy as np
list1=[1,2,3]
array1=np.array(list1)
list2=[3,5,8]
array2=np.array(list2)
array3=array1+array2
print("here is the array3",array3)
# Out:
# here is the array3 [ 4  7 11]
# [1, 2, 3, 3, 5, 8]

# %% [markdown]
# Identify their type using type()

# %%
import numpy as np
list1=[1,2,3]
array1=np.array(list1)
list2=[3,5,8]
array2=np.array(list2)
array3=array1+array2
print(type(list1))
print(type(list2))
print(type(array1))
print(type(array2))
print(type(array3))
print(array3)
print(np.ndim(array3))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# [ 4  7 11]
# 1

# %% [markdown]
# Perform mathematical operations on these datasets created - multiplication, division,
# powerof

# %%
import numpy as np
list1=[1,2,3]
array1=np.array(list1)
list2=[3,5,8]
array2=np.array(list2)
print("array2 multiplied by array1",array1*array2)
print("array2 divided by array1",array2/array1)
print("array2 raised to the power of array1:",array2**array1)
# Out:
# array2 multiplied by array1 [ 3 10 24]
# array2 divided by array1 [3.         2.5        2.66666667]
# array2 raised to the power of array1: [  3  25 512]

# %% [markdown]
# Combine text with Numpy fuction to generate a textual output - ”Addition of Two:
# array1 +array 2

# %%
import numpy as np
list1=[1,2,3]
array1=np.array(list1)
list2=[3,5,8]
array2=np.array(list2)
array3=array1+array2
print("adding array1 and array2",array1+array2)
# Out:
# adding array1 and array2 [ 4  7 11]

# %% [markdown]
# Implement np.sin(), log(), log2(), np.exp())

# %%
import numpy as np
array1=np.array([10,20,30])
#sine function
print("sine function: ",np.sin(array1))
#logarithm function
print("natural logarithm: ",np.log(array1))
print("base 10 logarithm: ",np.log10(array1))
print("base-2 logarthim: ",np.log2(array1))
#exponential function
print("exponential: ",np.exp(array1))
# Out:
# sine function:  [-0.54402111  0.91294525 -0.98803162]
# natural logarithm:  [2.30258509 2.99573227 3.40119738]
# base 10 logarithm:  [1.         1.30103    1.47712125]
# base-2 logarthim:  [3.32192809 4.32192809 4.9068906 ]
# exponential:  [2.20264658e+04 4.85165195e+08 1.06864746e+13]

# %% [markdown]
# part2 lab 1

# %% [markdown]
# Generate a Data set for Health Care using the following:
# people = [’kiran’, arun’, ’vijay’, ’varun’]
# age =[25, 30, 35, 40, 45]
# height =[145, 151, 165, 173]
# weight=[45, 55, 65, 75]

# %%
people=['kiran','arun','vijay','varun']
age=[25, 30, 35, 40, 45]
weight=[145, 151, 165, 173]
height=[45, 55, 65, 75]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Using the generated dataset given above. Generate the following graphs and justify the
# relationships among the vectors.
# 3. Scatter Plot

# %%
plt.scatter(weight,height)
plt.title("Relationship between weight and height of patients")
plt.ylabel("Height in meters")
plt.xlabel("weight of patients in kgs")
plt.show()

# %% [markdown]
# Bar Chart

# %%
plt.figure(figsize=(12,4))
plt.title("people's weight in kgs",fontsize=16,fontstyle='italic')
#main plot function bar
plt.bar(x=people, height=weight, width=0.6, color='orange',edgecolor='k',alpha=0.6)
plt.xlabel("people",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("weight(in kgs)",fontsize=15)
plt.show()

# %% [markdown]
# Histogram

# %%
import numpy as np
plt.figure(figsize=(7,5))
plt.hist(weight,color='red',edgecolor='k', alpha=0.75,bins=5)
plt.title("HISTOGRAM OF PATIENT WEIGHT",fontsize=18)
plt.xlabel("weight in kgs",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# Provide Graph Title, labels for X, Y axis with proper justification and explanation of
# the graph.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))
plt.title("people's weight in kgs",fontsize=16,fontstyle='italic')
#main plot function bar
plt.bar(x=people, height=weight, width=0.6, color='orange', edgecolor='k', alpha=0.6)
plt.xlabel("people",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("weight (in kgs)",fontsize=15)
plt.show()
